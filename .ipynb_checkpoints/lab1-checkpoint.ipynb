# %%
print("Lab 1 - Image Processing using Python")
# Out:
# Lab 1 - Image Processing using Python

# %%
import cv2
import matplotlib.pyplot as plt

# Load image using OpenCV
img = cv2.imread('images/cameraman.tif')

# Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display image
plt.imshow(img_rgb)
plt.title("Cameraman - OpenCV")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 8
#       5 img = cv2.imread('images/cameraman.tif')
#       7 # Convert BGR to RGB for correct display
# ----> 8 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      10 # Display image
#      11 plt.imshow(img_rgb)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm


img2 = Image.open('image/lena_gray_256.png')


plt.imshow(img2, cmap=cm.Greys_r)
plt.title("Lena - PIL")
plt.axis('off')
plt.show()
